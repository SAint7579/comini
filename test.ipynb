# %%
import pandas as pd

# %%
pd.read_csv('Data/tools_master.csv')
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0                0             0           0
# 1                1             1           0
# 2                2             2           0
# 3                3             3           0
# 4                4             4           0
# ...            ...           ...         ...
# 7330          7330           287           0
# 7331          7331           288           0
# 7332          7332           289           0
# 7333          7333           290           0
# 7334          7334           291           0
#
#                                                Headline  \
# 0     Bit TX C 6,3 (1/4 Zoll) kurze Ausführung für a...
# 1     Bit TX C 6,3 (1/4 Zoll) kurze Ausführung für a...
# 2     Bit TX C 6,3 (1/4 Zoll) kurze Ausführung für a...
# 3     Bit TX C 6,3 (1/4 Zoll) kurze Ausführung für a...
# 4     Bit TX C 6,3 (1/4 Zoll) kurze Ausführung für a...
# ...                                                 ...
# ...
